# %%
import random
from collections import defaultdict
import hashlib

# Load paragraphs from a file
def loadParagraphs(file_path):
    with open(file_path, 'r') as file:
        paragraphs = file.readlines()
    return [p.strip() for p in paragraphs if p.strip()]

# Generate k-shingles from a paragraph
def kShingles(paragraph, k):
    words = paragraph.split()
    shingles = set()
    for i in range(len(words) - k + 1):
        shingle = ' '.join(words[i:i + k])
        shingles.add(shingle)
    return shingles

# Hash shingles using SHA-256 and reduce them to 4-digit integers
def hashShingles(shingles):
    return {
        int(hashlib.sha256(shingle.encode()).hexdigest(), 16) % 10000 for shingle in shingles
    }

# Generate MinHash signatures
def minhashSignatures(sortedPairs, n):
    signatures = {
        doc_id: [float('inf')] * n for doc_id in sortedPairs.keys()
    }
    for i in range(n):
        randomHash = random.sample(range(1, 10001), len(sortedPairs))
        for doc_id, shingle_list in sortedPairs.items():
            for shingle in shingle_list:
                if signatures[doc_id][i] > randomHash[shingle % len(randomHash)]:
                    signatures[doc_id][i] = randomHash[shingle % len(randomHash)]
    return signatures

# Generate candidate pairs using Locality-Sensitive Hashing (LSH)
def candidatePairs(signatures, b, r):
    buckets = defaultdict(list)
    for doc_id, signature in signatures.items():
        for i in range(b):
            band = tuple(signature[i * r:(i + 1) * r])
            buckets[band].append(doc_id)
    return buckets

# Calculate Jaccard similarity between two sets of shingles
def jaccardSimilarity(shinglesA, shinglesB):
    intersection = len(shinglesA.intersection(shinglesB))
    union = len(shinglesA.union(shinglesB))
    return intersection / union if union != 0 else 0

# File path to the dataset
file_path = "Project2_dataset_similarity.txt"

# Load and process paragraphs
paragraphs = loadParagraphs(file_path)

# Shingling and hashing parameters
k = 5
shingleDict = {i: kShingles(paragraph, k) for i, paragraph in enumerate(paragraphs)}
hashedShingles = {i: hashShingles(shingles) for i, shingles in shingleDict.items()}

# MinHash parameters
n = 100
b = 3
r = 10

# Generate MinHash signatures and candidate pairs
signatures = minhashSignatures(hashedShingles, n)
candidates = candidatePairs(signatures, b, r)

# Identify similar pairs based on Jaccard similarity
similarPairs = []
threshold = 0.92
for bucket in candidates.values():
    if len(bucket) > 1:
        for i in range(len(bucket)):
            for j in range(i + 1, len(bucket)):
                shinglesA = shingleDict[bucket[i]]
                shinglesB = shingleDict[bucket[j]]

                similar = jaccardSimilarity(shinglesA, shinglesB)
                if similar >= threshold:
                    similarPairs.append((bucket[i], bucket[j], similar))

# Output similar pairs
for doc1, doc2, similar in similarPairs:
    print(f"Paragraphs {doc1} and {doc2} are similar with similarity {similar:.2f}")
# Out:
# Paragraphs 160 and 174 are similar with similarity 1.00
# Paragraphs 160 and 188 are similar with similarity 1.00
# Paragraphs 160 and 202 are similar with similarity 1.00
# Paragraphs 160 and 216 are similar with similarity 1.00
# Paragraphs 174 and 188 are similar with similarity 1.00
# Paragraphs 174 and 202 are similar with similarity 1.00
# Paragraphs 174 and 216 are similar with similarity 1.00
# Paragraphs 188 and 202 are similar with similarity 1.00
# Paragraphs 188 and 216 are similar with similarity 1.00
# Paragraphs 202 and 216 are similar with similarity 1.00
# Paragraphs 113 and 242 are similar with similarity 1.00
# Paragraphs 113 and 242 are similar with similarity 1.00
# Paragraphs 113 and 242 are similar with similarity 1.00
# Paragraphs 117 and 245 are similar with similarity 1.00
# Paragraphs 117 and 245 are similar with similarity 1.00
# Paragraphs 117 and 245 are similar with similarity 1.00
# Paragraphs 118 and 246 are similar with similarity 1.00
# Paragraphs 118 and 246 are similar with similarity 1.00
# Paragraphs 118 and 246 are similar with similarity 1.00
# Paragraphs 119 and 247 are similar with similarity 1.00
# Paragraphs 119 and 257 are similar with similarity 1.00
# Paragraphs 247 and 257 are similar with similarity 1.00
# Paragraphs 119 and 247 are similar with similarity 1.00
# Paragraphs 119 and 257 are similar with similarity 1.00
# Paragraphs 247 and 257 are similar with similarity 1.00
# Paragraphs 119 and 247 are similar with similarity 1.00
# Paragraphs 119 and 257 are similar with similarity 1.00
# Paragraphs 247 and 257 are similar with similarity 1.00
# Paragraphs 120 and 154 are similar with similarity 1.00
# Paragraphs 120 and 165 are similar with similarity 1.00
# Paragraphs 120 and 179 are similar with similarity 1.00
# Paragraphs 120 and 193 are similar with similarity 1.00
# Paragraphs 120 and 207 are similar with similarity 1.00
# Paragraphs 120 and 233 are similar with similarity 1.00
# Paragraphs 120 and 254 are similar with similarity 1.00
# Paragraphs 120 and 266 are similar with similarity 1.00
# Paragraphs 120 and 276 are similar with similarity 1.00
# Paragraphs 120 and 286 are similar with similarity 1.00
# Paragraphs 120 and 296 are similar with similarity 1.00
# Paragraphs 120 and 307 are similar with similarity 1.00
# Paragraphs 120 and 317 are similar with similarity 1.00
# Paragraphs 154 and 165 are similar with similarity 1.00
# Paragraphs 154 and 179 are similar with similarity 1.00
# Paragraphs 154 and 193 are similar with similarity 1.00
# Paragraphs 154 and 207 are similar with similarity 1.00
# Paragraphs 154 and 233 are similar with similarity 1.00
# Paragraphs 154 and 254 are similar with similarity 1.00
# Paragraphs 154 and 266 are similar with similarity 1.00
# Paragraphs 154 and 276 are similar with similarity 1.00
# Paragraphs 154 and 286 are similar with similarity 1.00
# Paragraphs 154 and 296 are similar with similarity 1.00
# Paragraphs 154 and 307 are similar with similarity 1.00
# Paragraphs 154 and 317 are similar with similarity 1.00
# Paragraphs 165 and 179 are similar with similarity 1.00
# Paragraphs 165 and 193 are similar with similarity 1.00
# Paragraphs 165 and 207 are similar with similarity 1.00
# Paragraphs 165 and 233 are similar with similarity 1.00
# Paragraphs 165 and 254 are similar with similarity 1.00
# Paragraphs 165 and 266 are similar with similarity 1.00
# Paragraphs 165 and 276 are similar with similarity 1.00
# Paragraphs 165 and 286 are similar with similarity 1.00
# Paragraphs 165 and 296 are similar with similarity 1.00
# Paragraphs 165 and 307 are similar with similarity 1.00
# Paragraphs 165 and 317 are similar with similarity 1.00
# Paragraphs 179 and 193 are similar with similarity 1.00
# Paragraphs 179 and 207 are similar with similarity 1.00
# Paragraphs 179 and 233 are similar with similarity 1.00
# Paragraphs 179 and 254 are similar with similarity 1.00
# Paragraphs 179 and 266 are similar with similarity 1.00
# Paragraphs 179 and 276 are similar with similarity 1.00
# Paragraphs 179 and 286 are similar with similarity 1.00
# Paragraphs 179 and 296 are similar with similarity 1.00
# Paragraphs 179 and 307 are similar with similarity 1.00
# Paragraphs 179 and 317 are similar with similarity 1.00
# Paragraphs 193 and 207 are similar with similarity 1.00
# Paragraphs 193 and 233 are similar with similarity 1.00
# Paragraphs 193 and 254 are similar with similarity 1.00
# Paragraphs 193 and 266 are similar with similarity 1.00
# Paragraphs 193 and 276 are similar with similarity 1.00
# Paragraphs 193 and 286 are similar with similarity 1.00
# Paragraphs 193 and 296 are similar with similarity 1.00
# Paragraphs 193 and 307 are similar with similarity 1.00
# Paragraphs 193 and 317 are similar with similarity 1.00
# Paragraphs 207 and 233 are similar with similarity 1.00
# Paragraphs 207 and 254 are similar with similarity 1.00
# Paragraphs 207 and 266 are similar with similarity 1.00
# Paragraphs 207 and 276 are similar with similarity 1.00
# Paragraphs 207 and 286 are similar with similarity 1.00
# Paragraphs 207 and 296 are similar with similarity 1.00
# Paragraphs 207 and 307 are similar with similarity 1.00
# Paragraphs 207 and 317 are similar with similarity 1.00
# Paragraphs 233 and 254 are similar with similarity 1.00
# Paragraphs 233 and 266 are similar with similarity 1.00
# Paragraphs 233 and 276 are similar with similarity 1.00
# Paragraphs 233 and 286 are similar with similarity 1.00
# Paragraphs 233 and 296 are similar with similarity 1.00
# Paragraphs 233 and 307 are similar with similarity 1.00
# Paragraphs 233 and 317 are similar with similarity 1.00
# Paragraphs 254 and 266 are similar with similarity 1.00
# Paragraphs 254 and 276 are similar with similarity 1.00
# Paragraphs 254 and 286 are similar with similarity 1.00
# Paragraphs 254 and 296 are similar with similarity 1.00
# Paragraphs 254 and 307 are similar with similarity 1.00
# Paragraphs 254 and 317 are similar with similarity 1.00
# Paragraphs 266 and 276 are similar with similarity 1.00
# Paragraphs 266 and 286 are similar with similarity 1.00
# Paragraphs 266 and 296 are similar with similarity 1.00
# Paragraphs 266 and 307 are similar with similarity 1.00
# Paragraphs 266 and 317 are similar with similarity 1.00
# Paragraphs 276 and 286 are similar with similarity 1.00
# Paragraphs 276 and 296 are similar with similarity 1.00
# Paragraphs 276 and 307 are similar with similarity 1.00
# Paragraphs 276 and 317 are similar with similarity 1.00
# Paragraphs 286 and 296 are similar with similarity 1.00
# Paragraphs 286 and 307 are similar with similarity 1.00
# Paragraphs 286 and 317 are similar with similarity 1.00
# Paragraphs 296 and 307 are similar with similarity 1.00
# Paragraphs 296 and 317 are similar with similarity 1.00
# Paragraphs 307 and 317 are similar with similarity 1.00
# Paragraphs 120 and 154 are similar with similarity 1.00
# Paragraphs 120 and 165 are similar with similarity 1.00
# Paragraphs 120 and 179 are similar with similarity 1.00
# Paragraphs 120 and 193 are similar with similarity 1.00
# Paragraphs 120 and 207 are similar with similarity 1.00
# Paragraphs 120 and 233 are similar with similarity 1.00
# Paragraphs 120 and 254 are similar with similarity 1.00
# Paragraphs 120 and 266 are similar with similarity 1.00
# Paragraphs 120 and 276 are similar with similarity 1.00
# Paragraphs 120 and 286 are similar with similarity 1.00
# Paragraphs 120 and 296 are similar with similarity 1.00
# Paragraphs 120 and 307 are similar with similarity 1.00
# Paragraphs 120 and 317 are similar with similarity 1.00
# Paragraphs 154 and 165 are similar with similarity 1.00
# Paragraphs 154 and 179 are similar with similarity 1.00
# Paragraphs 154 and 193 are similar with similarity 1.00
# Paragraphs 154 and 207 are similar with similarity 1.00
# Paragraphs 154 and 233 are similar with similarity 1.00
# Paragraphs 154 and 254 are similar with similarity 1.00
# Paragraphs 154 and 266 are similar with similarity 1.00
# Paragraphs 154 and 276 are similar with similarity 1.00
# Paragraphs 154 and 286 are similar with similarity 1.00
# Paragraphs 154 and 296 are similar with similarity 1.00
# Paragraphs 154 and 307 are similar with similarity 1.00
# Paragraphs 154 and 317 are similar with similarity 1.00
# Paragraphs 165 and 179 are similar with similarity 1.00
# Paragraphs 165 and 193 are similar with similarity 1.00
# Paragraphs 165 and 207 are similar with similarity 1.00
# Paragraphs 165 and 233 are similar with similarity 1.00
# Paragraphs 165 and 254 are similar with similarity 1.00
# Paragraphs 165 and 266 are similar with similarity 1.00
# Paragraphs 165 and 276 are similar with similarity 1.00
# Paragraphs 165 and 286 are similar with similarity 1.00
# Paragraphs 165 and 296 are similar with similarity 1.00
# Paragraphs 165 and 307 are similar with similarity 1.00
# Paragraphs 165 and 317 are similar with similarity 1.00
# Paragraphs 179 and 193 are similar with similarity 1.00
# Paragraphs 179 and 207 are similar with similarity 1.00
# Paragraphs 179 and 233 are similar with similarity 1.00
# Paragraphs 179 and 254 are similar with similarity 1.00
# Paragraphs 179 and 266 are similar with similarity 1.00
# Paragraphs 179 and 276 are similar with similarity 1.00
# Paragraphs 179 and 286 are similar with similarity 1.00
# Paragraphs 179 and 296 are similar with similarity 1.00
# Paragraphs 179 and 307 are similar with similarity 1.00
# Paragraphs 179 and 317 are similar with similarity 1.00
# Paragraphs 193 and 207 are similar with similarity 1.00
# Paragraphs 193 and 233 are similar with similarity 1.00
# Paragraphs 193 and 254 are similar with similarity 1.00
# Paragraphs 193 and 266 are similar with similarity 1.00
# Paragraphs 193 and 276 are similar with similarity 1.00
# Paragraphs 193 and 286 are similar with similarity 1.00
# Paragraphs 193 and 296 are similar with similarity 1.00
# Paragraphs 193 and 307 are similar with similarity 1.00
# Paragraphs 193 and 317 are similar with similarity 1.00
# Paragraphs 207 and 233 are similar with similarity 1.00
# Paragraphs 207 and 254 are similar with similarity 1.00
# Paragraphs 207 and 266 are similar with similarity 1.00
# Paragraphs 207 and 276 are similar with similarity 1.00
# Paragraphs 207 and 286 are similar with similarity 1.00
# Paragraphs 207 and 296 are similar with similarity 1.00
# Paragraphs 207 and 307 are similar with similarity 1.00
# Paragraphs 207 and 317 are similar with similarity 1.00
# Paragraphs 233 and 254 are similar with similarity 1.00
# Paragraphs 233 and 266 are similar with similarity 1.00
# Paragraphs 233 and 276 are similar with similarity 1.00
# Paragraphs 233 and 286 are similar with similarity 1.00
# Paragraphs 233 and 296 are similar with similarity 1.00
# Paragraphs 233 and 307 are similar with similarity 1.00
# Paragraphs 233 and 317 are similar with similarity 1.00
# Paragraphs 254 and 266 are similar with similarity 1.00
# Paragraphs 254 and 276 are similar with similarity 1.00
# Paragraphs 254 and 286 are similar with similarity 1.00
# Paragraphs 254 and 296 are similar with similarity 1.00
# Paragraphs 254 and 307 are similar with similarity 1.00
# Paragraphs 254 and 317 are similar with similarity 1.00
# Paragraphs 266 and 276 are similar with similarity 1.00
# Paragraphs 266 and 286 are similar with similarity 1.00
# Paragraphs 266 and 296 are similar with similarity 1.00
# Paragraphs 266 and 307 are similar with similarity 1.00
# Paragraphs 266 and 317 are similar with similarity 1.00
# Paragraphs 276 and 286 are similar with similarity 1.00
# Paragraphs 276 and 296 are similar with similarity 1.00
# Paragraphs 276 and 307 are similar with similarity 1.00
# Paragraphs 276 and 317 are similar with similarity 1.00
# Paragraphs 286 and 296 are similar with similarity 1.00
# Paragraphs 286 and 307 are similar with similarity 1.00
# Paragraphs 286 and 317 are similar with similarity 1.00
# Paragraphs 296 and 307 are similar with similarity 1.00
# Paragraphs 296 and 317 are similar with similarity 1.00
# Paragraphs 307 and 317 are similar with similarity 1.00
# Paragraphs 120 and 154 are similar with similarity 1.00
# Paragraphs 120 and 165 are similar with similarity 1.00
# Paragraphs 120 and 179 are similar with similarity 1.00
# Paragraphs 120 and 193 are similar with similarity 1.00
# Paragraphs 120 and 207 are similar with similarity 1.00
# Paragraphs 120 and 233 are similar with similarity 1.00
# Paragraphs 120 and 254 are similar with similarity 1.00
# Paragraphs 120 and 266 are similar with similarity 1.00
# Paragraphs 120 and 276 are similar with similarity 1.00
# Paragraphs 120 and 286 are similar with similarity 1.00
# Paragraphs 120 and 296 are similar with similarity 1.00
# Paragraphs 120 and 307 are similar with similarity 1.00
# Paragraphs 120 and 317 are similar with similarity 1.00
# Paragraphs 154 and 165 are similar with similarity 1.00
# Paragraphs 154 and 179 are similar with similarity 1.00
# Paragraphs 154 and 193 are similar with similarity 1.00
# Paragraphs 154 and 207 are similar with similarity 1.00
# Paragraphs 154 and 233 are similar with similarity 1.00
# Paragraphs 154 and 254 are similar with similarity 1.00
# Paragraphs 154 and 266 are similar with similarity 1.00
# Paragraphs 154 and 276 are similar with similarity 1.00
# Paragraphs 154 and 286 are similar with similarity 1.00
# Paragraphs 154 and 296 are similar with similarity 1.00
# Paragraphs 154 and 307 are similar with similarity 1.00
# Paragraphs 154 and 317 are similar with similarity 1.00
# Paragraphs 165 and 179 are similar with similarity 1.00
# Paragraphs 165 and 193 are similar with similarity 1.00
# Paragraphs 165 and 207 are similar with similarity 1.00
# Paragraphs 165 and 233 are similar with similarity 1.00
# Paragraphs 165 and 254 are similar with similarity 1.00
# Paragraphs 165 and 266 are similar with similarity 1.00
# Paragraphs 165 and 276 are similar with similarity 1.00
# Paragraphs 165 and 286 are similar with similarity 1.00
# Paragraphs 165 and 296 are similar with similarity 1.00
# Paragraphs 165 and 307 are similar with similarity 1.00
# Paragraphs 165 and 317 are similar with similarity 1.00
# Paragraphs 179 and 193 are similar with similarity 1.00
# Paragraphs 179 and 207 are similar with similarity 1.00
# Paragraphs 179 and 233 are similar with similarity 1.00
# Paragraphs 179 and 254 are similar with similarity 1.00
# Paragraphs 179 and 266 are similar with similarity 1.00
# Paragraphs 179 and 276 are similar with similarity 1.00
# Paragraphs 179 and 286 are similar with similarity 1.00
# Paragraphs 179 and 296 are similar with similarity 1.00
# Paragraphs 179 and 307 are similar with similarity 1.00
# Paragraphs 179 and 317 are similar with similarity 1.00
# Paragraphs 193 and 207 are similar with similarity 1.00
# Paragraphs 193 and 233 are similar with similarity 1.00
# Paragraphs 193 and 254 are similar with similarity 1.00
# Paragraphs 193 and 266 are similar with similarity 1.00
# Paragraphs 193 and 276 are similar with similarity 1.00
# Paragraphs 193 and 286 are similar with similarity 1.00
# Paragraphs 193 and 296 are similar with similarity 1.00
# Paragraphs 193 and 307 are similar with similarity 1.00
# Paragraphs 193 and 317 are similar with similarity 1.00
# Paragraphs 207 and 233 are similar with similarity 1.00
# Paragraphs 207 and 254 are similar with similarity 1.00
# Paragraphs 207 and 266 are similar with similarity 1.00
# Paragraphs 207 and 276 are similar with similarity 1.00
# Paragraphs 207 and 286 are similar with similarity 1.00
# Paragraphs 207 and 296 are similar with similarity 1.00
# Paragraphs 207 and 307 are similar with similarity 1.00
# Paragraphs 207 and 317 are similar with similarity 1.00
# Paragraphs 233 and 254 are similar with similarity 1.00
# Paragraphs 233 and 266 are similar with similarity 1.00
# Paragraphs 233 and 276 are similar with similarity 1.00
# Paragraphs 233 and 286 are similar with similarity 1.00
# Paragraphs 233 and 296 are similar with similarity 1.00
# Paragraphs 233 and 307 are similar with similarity 1.00
# Paragraphs 233 and 317 are similar with similarity 1.00
# Paragraphs 254 and 266 are similar with similarity 1.00
# Paragraphs 254 and 276 are similar with similarity 1.00
# Paragraphs 254 and 286 are similar with similarity 1.00
# Paragraphs 254 and 296 are similar with similarity 1.00
# Paragraphs 254 and 307 are similar with similarity 1.00
# Paragraphs 254 and 317 are similar with similarity 1.00
# Paragraphs 266 and 276 are similar with similarity 1.00
# Paragraphs 266 and 286 are similar with similarity 1.00
# Paragraphs 266 and 296 are similar with similarity 1.00
# Paragraphs 266 and 307 are similar with similarity 1.00
# Paragraphs 266 and 317 are similar with similarity 1.00
# Paragraphs 276 and 286 are similar with similarity 1.00
# Paragraphs 276 and 296 are similar with similarity 1.00
# Paragraphs 276 and 307 are similar with similarity 1.00
# Paragraphs 276 and 317 are similar with similarity 1.00
# Paragraphs 286 and 296 are similar with similarity 1.00
# Paragraphs 286 and 307 are similar with similarity 1.00
# Paragraphs 286 and 317 are similar with similarity 1.00
# Paragraphs 296 and 307 are similar with similarity 1.00
# Paragraphs 296 and 317 are similar with similarity 1.00
# Paragraphs 307 and 317 are similar with similarity 1.00
# Paragraphs 121 and 155 are similar with similarity 1.00
# Paragraphs 121 and 234 are similar with similarity 1.00
# Paragraphs 121 and 255 are similar with similarity 1.00
# Paragraphs 121 and 267 are similar with similarity 1.00
# Paragraphs 121 and 277 are similar with similarity 1.00
# Paragraphs 121 and 287 are similar with similarity 1.00
# Paragraphs 121 and 297 are similar with similarity 1.00
# Paragraphs 121 and 308 are similar with similarity 1.00
# Paragraphs 121 and 318 are similar with similarity 1.00
# Paragraphs 155 and 234 are similar with similarity 1.00
# Paragraphs 155 and 255 are similar with similarity 1.00
# Paragraphs 155 and 267 are similar with similarity 1.00
# Paragraphs 155 and 277 are similar with similarity 1.00
# Paragraphs 155 and 287 are similar with similarity 1.00
# Paragraphs 155 and 297 are similar with similarity 1.00
# Paragraphs 155 and 308 are similar with similarity 1.00
# Paragraphs 155 and 318 are similar with similarity 1.00
# Paragraphs 234 and 255 are similar with similarity 1.00
# Paragraphs 234 and 267 are similar with similarity 1.00
# Paragraphs 234 and 277 are similar with similarity 1.00
# Paragraphs 234 and 287 are similar with similarity 1.00
# Paragraphs 234 and 297 are similar with similarity 1.00
# Paragraphs 234 and 308 are similar with similarity 1.00
# Paragraphs 234 and 318 are similar with similarity 1.00
# Paragraphs 255 and 267 are similar with similarity 1.00
# Paragraphs 255 and 277 are similar with similarity 1.00
# Paragraphs 255 and 287 are similar with similarity 1.00
# Paragraphs 255 and 297 are similar with similarity 1.00
# Paragraphs 255 and 308 are similar with similarity 1.00
# Paragraphs 255 and 318 are similar with similarity 1.00
# Paragraphs 267 and 277 are similar with similarity 1.00
# Paragraphs 267 and 287 are similar with similarity 1.00
# Paragraphs 267 and 297 are similar with similarity 1.00
# Paragraphs 267 and 308 are similar with similarity 1.00
# Paragraphs 267 and 318 are similar with similarity 1.00
# Paragraphs 277 and 287 are similar with similarity 1.00
# Paragraphs 277 and 297 are similar with similarity 1.00
# Paragraphs 277 and 308 are similar with similarity 1.00
# Paragraphs 277 and 318 are similar with similarity 1.00
# Paragraphs 287 and 297 are similar with similarity 1.00
# Paragraphs 287 and 308 are similar with similarity 1.00
# Paragraphs 287 and 318 are similar with similarity 1.00
# Paragraphs 297 and 308 are similar with similarity 1.00
# Paragraphs 297 and 318 are similar with similarity 1.00
# Paragraphs 308 and 318 are similar with similarity 1.00
# Paragraphs 121 and 155 are similar with similarity 1.00
# Paragraphs 121 and 234 are similar with similarity 1.00
# Paragraphs 121 and 255 are similar with similarity 1.00
# Paragraphs 121 and 267 are similar with similarity 1.00
# Paragraphs 121 and 277 are similar with similarity 1.00
# Paragraphs 121 and 287 are similar with similarity 1.00
# Paragraphs 121 and 297 are similar with similarity 1.00
# Paragraphs 121 and 308 are similar with similarity 1.00
# Paragraphs 121 and 318 are similar with similarity 1.00
# Paragraphs 155 and 234 are similar with similarity 1.00
# Paragraphs 155 and 255 are similar with similarity 1.00
# Paragraphs 155 and 267 are similar with similarity 1.00
# Paragraphs 155 and 277 are similar with similarity 1.00
# Paragraphs 155 and 287 are similar with similarity 1.00
# Paragraphs 155 and 297 are similar with similarity 1.00
# Paragraphs 155 and 308 are similar with similarity 1.00
# Paragraphs 155 and 318 are similar with similarity 1.00
# Paragraphs 234 and 255 are similar with similarity 1.00
# Paragraphs 234 and 267 are similar with similarity 1.00
# Paragraphs 234 and 277 are similar with similarity 1.00
# Paragraphs 234 and 287 are similar with similarity 1.00
# Paragraphs 234 and 297 are similar with similarity 1.00
# Paragraphs 234 and 308 are similar with similarity 1.00
# Paragraphs 234 and 318 are similar with similarity 1.00
# Paragraphs 255 and 267 are similar with similarity 1.00
# Paragraphs 255 and 277 are similar with similarity 1.00
# Paragraphs 255 and 287 are similar with similarity 1.00
# Paragraphs 255 and 297 are similar with similarity 1.00
# Paragraphs 255 and 308 are similar with similarity 1.00
# Paragraphs 255 and 318 are similar with similarity 1.00
# Paragraphs 267 and 277 are similar with similarity 1.00
# Paragraphs 267 and 287 are similar with similarity 1.00
# Paragraphs 267 and 297 are similar with similarity 1.00
# Paragraphs 267 and 308 are similar with similarity 1.00
# Paragraphs 267 and 318 are similar with similarity 1.00
# Paragraphs 277 and 287 are similar with similarity 1.00
# Paragraphs 277 and 297 are similar with similarity 1.00
# Paragraphs 277 and 308 are similar with similarity 1.00
# Paragraphs 277 and 318 are similar with similarity 1.00
# Paragraphs 287 and 297 are similar with similarity 1.00
# Paragraphs 287 and 308 are similar with similarity 1.00
# Paragraphs 287 and 318 are similar with similarity 1.00
# Paragraphs 297 and 308 are similar with similarity 1.00
# Paragraphs 297 and 318 are similar with similarity 1.00
# Paragraphs 308 and 318 are similar with similarity 1.00
# Paragraphs 121 and 155 are similar with similarity 1.00
# Paragraphs 121 and 234 are similar with similarity 1.00
# Paragraphs 121 and 255 are similar with similarity 1.00
# Paragraphs 121 and 267 are similar with similarity 1.00
# Paragraphs 121 and 277 are similar with similarity 1.00
# Paragraphs 121 and 287 are similar with similarity 1.00
# Paragraphs 121 and 297 are similar with similarity 1.00
# Paragraphs 121 and 308 are similar with similarity 1.00
# Paragraphs 121 and 318 are similar with similarity 1.00
# Paragraphs 155 and 234 are similar with similarity 1.00
# Paragraphs 155 and 255 are similar with similarity 1.00
# Paragraphs 155 and 267 are similar with similarity 1.00
# Paragraphs 155 and 277 are similar with similarity 1.00
# Paragraphs 155 and 287 are similar with similarity 1.00
# Paragraphs 155 and 297 are similar with similarity 1.00
# Paragraphs 155 and 308 are similar with similarity 1.00
# Paragraphs 155 and 318 are similar with similarity 1.00
# Paragraphs 234 and 255 are similar with similarity 1.00
# Paragraphs 234 and 267 are similar with similarity 1.00
# Paragraphs 234 and 277 are similar with similarity 1.00
# Paragraphs 234 and 287 are similar with similarity 1.00
# Paragraphs 234 and 297 are similar with similarity 1.00
# Paragraphs 234 and 308 are similar with similarity 1.00
# Paragraphs 234 and 318 are similar with similarity 1.00
# Paragraphs 255 and 267 are similar with similarity 1.00
# Paragraphs 255 and 277 are similar with similarity 1.00
# Paragraphs 255 and 287 are similar with similarity 1.00
# Paragraphs 255 and 297 are similar with similarity 1.00
# Paragraphs 255 and 308 are similar with similarity 1.00
# Paragraphs 255 and 318 are similar with similarity 1.00
# Paragraphs 267 and 277 are similar with similarity 1.00
# Paragraphs 267 and 287 are similar with similarity 1.00
# Paragraphs 267 and 297 are similar with similarity 1.00
# Paragraphs 267 and 308 are similar with similarity 1.00
# Paragraphs 267 and 318 are similar with similarity 1.00
# Paragraphs 277 and 287 are similar with similarity 1.00
# Paragraphs 277 and 297 are similar with similarity 1.00
# Paragraphs 277 and 308 are similar with similarity 1.00
# Paragraphs 277 and 318 are similar with similarity 1.00
# Paragraphs 287 and 297 are similar with similarity 1.00
# Paragraphs 287 and 308 are similar with similarity 1.00
# Paragraphs 287 and 318 are similar with similarity 1.00
# Paragraphs 297 and 308 are similar with similarity 1.00
# Paragraphs 297 and 318 are similar with similarity 1.00
# Paragraphs 308 and 318 are similar with similarity 1.00
# Paragraphs 123 and 241 are similar with similarity 1.00
# Paragraphs 123 and 259 are similar with similarity 1.00
# Paragraphs 123 and 270 are similar with similarity 1.00
# Paragraphs 123 and 280 are similar with similarity 1.00
# Paragraphs 123 and 290 are similar with similarity 1.00
# Paragraphs 123 and 300 are similar with similarity 1.00
# Paragraphs 123 and 311 are similar with similarity 1.00
# Paragraphs 241 and 259 are similar with similarity 1.00
# Paragraphs 241 and 270 are similar with similarity 1.00
# Paragraphs 241 and 280 are similar with similarity 1.00
# Paragraphs 241 and 290 are similar with similarity 1.00
# Paragraphs 241 and 300 are similar with similarity 1.00
# Paragraphs 241 and 311 are similar with similarity 1.00
# Paragraphs 259 and 270 are similar with similarity 1.00
# Paragraphs 259 and 280 are similar with similarity 1.00
# Paragraphs 259 and 290 are similar with similarity 1.00
# Paragraphs 259 and 300 are similar with similarity 1.00
# Paragraphs 259 and 311 are similar with similarity 1.00
# Paragraphs 270 and 280 are similar with similarity 1.00
# Paragraphs 270 and 290 are similar with similarity 1.00
# Paragraphs 270 and 300 are similar with similarity 1.00
# Paragraphs 270 and 311 are similar with similarity 1.00
# Paragraphs 280 and 290 are similar with similarity 1.00
# Paragraphs 280 and 300 are similar with similarity 1.00
# Paragraphs 280 and 311 are similar with similarity 1.00
# Paragraphs 290 and 300 are similar with similarity 1.00
# Paragraphs 290 and 311 are similar with similarity 1.00
# Paragraphs 300 and 311 are similar with similarity 1.00
# Paragraphs 123 and 241 are similar with similarity 1.00
# Paragraphs 123 and 259 are similar with similarity 1.00
# Paragraphs 123 and 270 are similar with similarity 1.00
# Paragraphs 123 and 280 are similar with similarity 1.00
# Paragraphs 123 and 290 are similar with similarity 1.00
# Paragraphs 123 and 300 are similar with similarity 1.00
# Paragraphs 123 and 311 are similar with similarity 1.00
# Paragraphs 241 and 259 are similar with similarity 1.00
# Paragraphs 241 and 270 are similar with similarity 1.00
# Paragraphs 241 and 280 are similar with similarity 1.00
# Paragraphs 241 and 290 are similar with similarity 1.00
# Paragraphs 241 and 300 are similar with similarity 1.00
# Paragraphs 241 and 311 are similar with similarity 1.00
# Paragraphs 259 and 270 are similar with similarity 1.00
# Paragraphs 259 and 280 are similar with similarity 1.00
# Paragraphs 259 and 290 are similar with similarity 1.00
# Paragraphs 259 and 300 are similar with similarity 1.00
# Paragraphs 259 and 311 are similar with similarity 1.00
# Paragraphs 270 and 280 are similar with similarity 1.00
# Paragraphs 270 and 290 are similar with similarity 1.00
# Paragraphs 270 and 300 are similar with similarity 1.00
# Paragraphs 270 and 311 are similar with similarity 1.00
# Paragraphs 280 and 290 are similar with similarity 1.00
# Paragraphs 280 and 300 are similar with similarity 1.00
# Paragraphs 280 and 311 are similar with similarity 1.00
# Paragraphs 290 and 300 are similar with similarity 1.00
# Paragraphs 290 and 311 are similar with similarity 1.00
# Paragraphs 300 and 311 are similar with similarity 1.00
# Paragraphs 123 and 241 are similar with similarity 1.00
# Paragraphs 123 and 259 are similar with similarity 1.00
# Paragraphs 123 and 270 are similar with similarity 1.00
# Paragraphs 123 and 280 are similar with similarity 1.00
# Paragraphs 123 and 290 are similar with similarity 1.00
# Paragraphs 123 and 300 are similar with similarity 1.00
# Paragraphs 123 and 311 are similar with similarity 1.00
# Paragraphs 241 and 259 are similar with similarity 1.00
# Paragraphs 241 and 270 are similar with similarity 1.00
# Paragraphs 241 and 280 are similar with similarity 1.00
# Paragraphs 241 and 290 are similar with similarity 1.00
# Paragraphs 241 and 300 are similar with similarity 1.00
# Paragraphs 241 and 311 are similar with similarity 1.00
# Paragraphs 259 and 270 are similar with similarity 1.00
# Paragraphs 259 and 280 are similar with similarity 1.00
# Paragraphs 259 and 290 are similar with similarity 1.00
# Paragraphs 259 and 300 are similar with similarity 1.00
# Paragraphs 259 and 311 are similar with similarity 1.00
# Paragraphs 270 and 280 are similar with similarity 1.00
# Paragraphs 270 and 290 are similar with similarity 1.00
# Paragraphs 270 and 300 are similar with similarity 1.00
# Paragraphs 270 and 311 are similar with similarity 1.00
# Paragraphs 280 and 290 are similar with similarity 1.00
# Paragraphs 280 and 300 are similar with similarity 1.00
# Paragraphs 280 and 311 are similar with similarity 1.00
# Paragraphs 290 and 300 are similar with similarity 1.00
# Paragraphs 290 and 311 are similar with similarity 1.00
# Paragraphs 300 and 311 are similar with similarity 1.00
# Paragraphs 124 and 240 are similar with similarity 1.00
# Paragraphs 258 and 269 are similar with similarity 1.00
# Paragraphs 258 and 279 are similar with similarity 1.00
# Paragraphs 258 and 289 are similar with similarity 1.00
# Paragraphs 258 and 299 are similar with similarity 1.00
# Paragraphs 258 and 310 are similar with similarity 1.00
# Paragraphs 258 and 320 are similar with similarity 1.00
# Paragraphs 269 and 279 are similar with similarity 1.00
# Paragraphs 269 and 289 are similar with similarity 1.00
# Paragraphs 269 and 299 are similar with similarity 1.00
# Paragraphs 269 and 310 are similar with similarity 1.00
# Paragraphs 269 and 320 are similar with similarity 1.00
# Paragraphs 279 and 289 are similar with similarity 1.00
# Paragraphs 279 and 299 are similar with similarity 1.00
# Paragraphs 279 and 310 are similar with similarity 1.00
# Paragraphs 279 and 320 are similar with similarity 1.00
# Paragraphs 289 and 299 are similar with similarity 1.00
# Paragraphs 289 and 310 are similar with similarity 1.00
# Paragraphs 289 and 320 are similar with similarity 1.00
# Paragraphs 299 and 310 are similar with similarity 1.00
# Paragraphs 299 and 320 are similar with similarity 1.00
# Paragraphs 310 and 320 are similar with similarity 1.00
# Paragraphs 124 and 240 are similar with similarity 1.00
# Paragraphs 172 and 186 are similar with similarity 1.00
# Paragraphs 172 and 200 are similar with similarity 1.00
# Paragraphs 172 and 214 are similar with similarity 1.00
# Paragraphs 186 and 200 are similar with similarity 1.00
# Paragraphs 186 and 214 are similar with similarity 1.00
# Paragraphs 200 and 214 are similar with similarity 1.00
# Paragraphs 124 and 240 are similar with similarity 1.00
# Paragraphs 126 and 158 are similar with similarity 1.00
# Paragraphs 126 and 231 are similar with similarity 1.00
# Paragraphs 158 and 231 are similar with similarity 1.00
# Paragraphs 126 and 158 are similar with similarity 1.00
# Paragraphs 126 and 231 are similar with similarity 1.00
# Paragraphs 158 and 231 are similar with similarity 1.00
# Paragraphs 126 and 158 are similar with similarity 1.00
# Paragraphs 126 and 231 are similar with similarity 1.00
# Paragraphs 158 and 231 are similar with similarity 1.00
# Paragraphs 130 and 168 are similar with similarity 1.00
# Paragraphs 130 and 182 are similar with similarity 1.00
# Paragraphs 130 and 196 are similar with similarity 1.00
# Paragraphs 130 and 210 are similar with similarity 1.00
# Paragraphs 130 and 243 are similar with similarity 1.00
# Paragraphs 168 and 182 are similar with similarity 1.00
# Paragraphs 168 and 196 are similar with similarity 1.00
# Paragraphs 168 and 210 are similar with similarity 1.00
# Paragraphs 168 and 243 are similar with similarity 1.00
# Paragraphs 182 and 196 are similar with similarity 1.00
# Paragraphs 182 and 210 are similar with similarity 1.00
# Paragraphs 182 and 243 are similar with similarity 1.00
# Paragraphs 196 and 210 are similar with similarity 1.00
# Paragraphs 196 and 243 are similar with similarity 1.00
# Paragraphs 210 and 243 are similar with similarity 1.00
# Paragraphs 130 and 168 are similar with similarity 1.00
# Paragraphs 130 and 182 are similar with similarity 1.00
# Paragraphs 130 and 196 are similar with similarity 1.00
# Paragraphs 130 and 210 are similar with similarity 1.00
# Paragraphs 130 and 243 are similar with similarity 1.00
# Paragraphs 168 and 182 are similar with similarity 1.00
# Paragraphs 168 and 196 are similar with similarity 1.00
# Paragraphs 168 and 210 are similar with similarity 1.00
# Paragraphs 168 and 243 are similar with similarity 1.00
# Paragraphs 182 and 196 are similar with similarity 1.00
# Paragraphs 182 and 210 are similar with similarity 1.00
# Paragraphs 182 and 243 are similar with similarity 1.00
# Paragraphs 196 and 210 are similar with similarity 1.00
# Paragraphs 196 and 243 are similar with similarity 1.00
# Paragraphs 210 and 243 are similar with similarity 1.00
# Paragraphs 130 and 168 are similar with similarity 1.00
# Paragraphs 130 and 182 are similar with similarity 1.00
# Paragraphs 130 and 196 are similar with similarity 1.00
# Paragraphs 130 and 210 are similar with similarity 1.00
# Paragraphs 130 and 243 are similar with similarity 1.00
# Paragraphs 168 and 182 are similar with similarity 1.00
# Paragraphs 168 and 196 are similar with similarity 1.00
# Paragraphs 168 and 210 are similar with similarity 1.00
# Paragraphs 168 and 243 are similar with similarity 1.00
# Paragraphs 182 and 196 are similar with similarity 1.00
# Paragraphs 182 and 210 are similar with similarity 1.00
# Paragraphs 182 and 243 are similar with similarity 1.00
# Paragraphs 196 and 210 are similar with similarity 1.00
# Paragraphs 196 and 243 are similar with similarity 1.00
# Paragraphs 210 and 243 are similar with similarity 1.00
# Paragraphs 131 and 244 are similar with similarity 1.00
# Paragraphs 131 and 244 are similar with similarity 1.00
# Paragraphs 131 and 244 are similar with similarity 1.00
# Paragraphs 132 and 163 are similar with similarity 1.00
# Paragraphs 132 and 177 are similar with similarity 1.00
# Paragraphs 132 and 191 are similar with similarity 1.00
# Paragraphs 132 and 205 are similar with similarity 1.00
# Paragraphs 132 and 219 are similar with similarity 1.00
# Paragraphs 132 and 226 are similar with similarity 1.00
# Paragraphs 132 and 260 are similar with similarity 1.00
# Paragraphs 132 and 271 are similar with similarity 1.00
# Paragraphs 132 and 281 are similar with similarity 1.00
# Paragraphs 132 and 291 are similar with similarity 1.00
# Paragraphs 132 and 301 are similar with similarity 1.00
# Paragraphs 132 and 312 are similar with similarity 1.00
# Paragraphs 163 and 177 are similar with similarity 1.00
# Paragraphs 163 and 191 are similar with similarity 1.00
# Paragraphs 163 and 205 are similar with similarity 1.00
# Paragraphs 163 and 219 are similar with similarity 1.00
# Paragraphs 163 and 226 are similar with similarity 1.00
# Paragraphs 163 and 260 are similar with similarity 1.00
# Paragraphs 163 and 271 are similar with similarity 1.00
# Paragraphs 163 and 281 are similar with similarity 1.00
# Paragraphs 163 and 291 are similar with similarity 1.00
# Paragraphs 163 and 301 are similar with similarity 1.00
# Paragraphs 163 and 312 are similar with similarity 1.00
# Paragraphs 177 and 191 are similar with similarity 1.00
# Paragraphs 177 and 205 are similar with similarity 1.00
# Paragraphs 177 and 219 are similar with similarity 1.00
# Paragraphs 177 and 226 are similar with similarity 1.00
# Paragraphs 177 and 260 are similar with similarity 1.00
# Paragraphs 177 and 271 are similar with similarity 1.00
# Paragraphs 177 and 281 are similar with similarity 1.00
# Paragraphs 177 and 291 are similar with similarity 1.00
# Paragraphs 177 and 301 are similar with similarity 1.00
# Paragraphs 177 and 312 are similar with similarity 1.00
# Paragraphs 191 and 205 are similar with similarity 1.00
# Paragraphs 191 and 219 are similar with similarity 1.00
# Paragraphs 191 and 226 are similar with similarity 1.00
# Paragraphs 191 and 260 are similar with similarity 1.00
# Paragraphs 191 and 271 are similar with similarity 1.00
# Paragraphs 191 and 281 are similar with similarity 1.00
# Paragraphs 191 and 291 are similar with similarity 1.00
# Paragraphs 191 and 301 are similar with similarity 1.00
# Paragraphs 191 and 312 are similar with similarity 1.00
# Paragraphs 205 and 219 are similar with similarity 1.00
# Paragraphs 205 and 226 are similar with similarity 1.00
# Paragraphs 205 and 260 are similar with similarity 1.00
# Paragraphs 205 and 271 are similar with similarity 1.00
# Paragraphs 205 and 281 are similar with similarity 1.00
# Paragraphs 205 and 291 are similar with similarity 1.00
# Paragraphs 205 and 301 are similar with similarity 1.00
# Paragraphs 205 and 312 are similar with similarity 1.00
# Paragraphs 219 and 226 are similar with similarity 1.00
# Paragraphs 219 and 260 are similar with similarity 1.00
# Paragraphs 219 and 271 are similar with similarity 1.00
# Paragraphs 219 and 281 are similar with similarity 1.00
# Paragraphs 219 and 291 are similar with similarity 1.00
# Paragraphs 219 and 301 are similar with similarity 1.00
# Paragraphs 219 and 312 are similar with similarity 1.00
# Paragraphs 226 and 260 are similar with similarity 1.00
# Paragraphs 226 and 271 are similar with similarity 1.00
# Paragraphs 226 and 281 are similar with similarity 1.00
# Paragraphs 226 and 291 are similar with similarity 1.00
# Paragraphs 226 and 301 are similar with similarity 1.00
# Paragraphs 226 and 312 are similar with similarity 1.00
# Paragraphs 260 and 271 are similar with similarity 1.00
# Paragraphs 260 and 281 are similar with similarity 1.00
# Paragraphs 260 and 291 are similar with similarity 1.00
# Paragraphs 260 and 301 are similar with similarity 1.00
# Paragraphs 260 and 312 are similar with similarity 1.00
# Paragraphs 271 and 281 are similar with similarity 1.00
# Paragraphs 271 and 291 are similar with similarity 1.00
# Paragraphs 271 and 301 are similar with similarity 1.00
# Paragraphs 271 and 312 are similar with similarity 1.00
# Paragraphs 281 and 291 are similar with similarity 1.00
# Paragraphs 281 and 301 are similar with similarity 1.00
# Paragraphs 281 and 312 are similar with similarity 1.00
# Paragraphs 291 and 301 are similar with similarity 1.00
# Paragraphs 291 and 312 are similar with similarity 1.00
# Paragraphs 301 and 312 are similar with similarity 1.00
# Paragraphs 132 and 163 are similar with similarity 1.00
# Paragraphs 132 and 177 are similar with similarity 1.00
# Paragraphs 132 and 191 are similar with similarity 1.00
# Paragraphs 132 and 205 are similar with similarity 1.00
# Paragraphs 132 and 219 are similar with similarity 1.00
# Paragraphs 132 and 226 are similar with similarity 1.00
# Paragraphs 132 and 260 are similar with similarity 1.00
# Paragraphs 132 and 271 are similar with similarity 1.00
# Paragraphs 132 and 281 are similar with similarity 1.00
# Paragraphs 132 and 291 are similar with similarity 1.00
# Paragraphs 132 and 301 are similar with similarity 1.00
# Paragraphs 132 and 312 are similar with similarity 1.00
# Paragraphs 163 and 177 are similar with similarity 1.00
# Paragraphs 163 and 191 are similar with similarity 1.00
# Paragraphs 163 and 205 are similar with similarity 1.00
# Paragraphs 163 and 219 are similar with similarity 1.00
# Paragraphs 163 and 226 are similar with similarity 1.00
# Paragraphs 163 and 260 are similar with similarity 1.00
# Paragraphs 163 and 271 are similar with similarity 1.00
# Paragraphs 163 and 281 are similar with similarity 1.00
# Paragraphs 163 and 291 are similar with similarity 1.00
# Paragraphs 163 and 301 are similar with similarity 1.00
# Paragraphs 163 and 312 are similar with similarity 1.00
# Paragraphs 177 and 191 are similar with similarity 1.00
# Paragraphs 177 and 205 are similar with similarity 1.00
# Paragraphs 177 and 219 are similar with similarity 1.00
# Paragraphs 177 and 226 are similar with similarity 1.00
# Paragraphs 177 and 260 are similar with similarity 1.00
# Paragraphs 177 and 271 are similar with similarity 1.00
# Paragraphs 177 and 281 are similar with similarity 1.00
# Paragraphs 177 and 291 are similar with similarity 1.00
# Paragraphs 177 and 301 are similar with similarity 1.00
# Paragraphs 177 and 312 are similar with similarity 1.00
# Paragraphs 191 and 205 are similar with similarity 1.00
# Paragraphs 191 and 219 are similar with similarity 1.00
# Paragraphs 191 and 226 are similar with similarity 1.00
# Paragraphs 191 and 260 are similar with similarity 1.00
# Paragraphs 191 and 271 are similar with similarity 1.00
# Paragraphs 191 and 281 are similar with similarity 1.00
# Paragraphs 191 and 291 are similar with similarity 1.00
# Paragraphs 191 and 301 are similar with similarity 1.00
# Paragraphs 191 and 312 are similar with similarity 1.00
# Paragraphs 205 and 219 are similar with similarity 1.00
# Paragraphs 205 and 226 are similar with similarity 1.00
# Paragraphs 205 and 260 are similar with similarity 1.00
# Paragraphs 205 and 271 are similar with similarity 1.00
# Paragraphs 205 and 281 are similar with similarity 1.00
# Paragraphs 205 and 291 are similar with similarity 1.00
# Paragraphs 205 and 301 are similar with similarity 1.00
# Paragraphs 205 and 312 are similar with similarity 1.00
# Paragraphs 219 and 226 are similar with similarity 1.00
# Paragraphs 219 and 260 are similar with similarity 1.00
# Paragraphs 219 and 271 are similar with similarity 1.00
# Paragraphs 219 and 281 are similar with similarity 1.00
# Paragraphs 219 and 291 are similar with similarity 1.00
# Paragraphs 219 and 301 are similar with similarity 1.00
# Paragraphs 219 and 312 are similar with similarity 1.00
# Paragraphs 226 and 260 are similar with similarity 1.00
# Paragraphs 226 and 271 are similar with similarity 1.00
# Paragraphs 226 and 281 are similar with similarity 1.00
# Paragraphs 226 and 291 are similar with similarity 1.00
# Paragraphs 226 and 301 are similar with similarity 1.00
# Paragraphs 226 and 312 are similar with similarity 1.00
# Paragraphs 260 and 271 are similar with similarity 1.00
# Paragraphs 260 and 281 are similar with similarity 1.00
# Paragraphs 260 and 291 are similar with similarity 1.00
# Paragraphs 260 and 301 are similar with similarity 1.00
# Paragraphs 260 and 312 are similar with similarity 1.00
# Paragraphs 271 and 281 are similar with similarity 1.00
# Paragraphs 271 and 291 are similar with similarity 1.00
# Paragraphs 271 and 301 are similar with similarity 1.00
# Paragraphs 271 and 312 are similar with similarity 1.00
# Paragraphs 281 and 291 are similar with similarity 1.00
# Paragraphs 281 and 301 are similar with similarity 1.00
# Paragraphs 281 and 312 are similar with similarity 1.00
# Paragraphs 291 and 301 are similar with similarity 1.00
# Paragraphs 291 and 312 are similar with similarity 1.00
# Paragraphs 301 and 312 are similar with similarity 1.00
# Paragraphs 132 and 163 are similar with similarity 1.00
# Paragraphs 132 and 177 are similar with similarity 1.00
# Paragraphs 132 and 191 are similar with similarity 1.00
# Paragraphs 132 and 205 are similar with similarity 1.00
# Paragraphs 132 and 219 are similar with similarity 1.00
# Paragraphs 132 and 226 are similar with similarity 1.00
# Paragraphs 132 and 260 are similar with similarity 1.00
# Paragraphs 132 and 271 are similar with similarity 1.00
# Paragraphs 132 and 281 are similar with similarity 1.00
# Paragraphs 132 and 291 are similar with similarity 1.00
# Paragraphs 132 and 301 are similar with similarity 1.00
# Paragraphs 132 and 312 are similar with similarity 1.00
# Paragraphs 163 and 177 are similar with similarity 1.00
# Paragraphs 163 and 191 are similar with similarity 1.00
# Paragraphs 163 and 205 are similar with similarity 1.00
# Paragraphs 163 and 219 are similar with similarity 1.00
# Paragraphs 163 and 226 are similar with similarity 1.00
# Paragraphs 163 and 260 are similar with similarity 1.00
# Paragraphs 163 and 271 are similar with similarity 1.00
# Paragraphs 163 and 281 are similar with similarity 1.00
# Paragraphs 163 and 291 are similar with similarity 1.00
# Paragraphs 163 and 301 are similar with similarity 1.00
# Paragraphs 163 and 312 are similar with similarity 1.00
# Paragraphs 177 and 191 are similar with similarity 1.00
# Paragraphs 177 and 205 are similar with similarity 1.00
# Paragraphs 177 and 219 are similar with similarity 1.00
# Paragraphs 177 and 226 are similar with similarity 1.00
# Paragraphs 177 and 260 are similar with similarity 1.00
# Paragraphs 177 and 271 are similar with similarity 1.00
# Paragraphs 177 and 281 are similar with similarity 1.00
# Paragraphs 177 and 291 are similar with similarity 1.00
# Paragraphs 177 and 301 are similar with similarity 1.00
# Paragraphs 177 and 312 are similar with similarity 1.00
# Paragraphs 191 and 205 are similar with similarity 1.00
# Paragraphs 191 and 219 are similar with similarity 1.00
# Paragraphs 191 and 226 are similar with similarity 1.00
# Paragraphs 191 and 260 are similar with similarity 1.00
# Paragraphs 191 and 271 are similar with similarity 1.00
# Paragraphs 191 and 281 are similar with similarity 1.00
# Paragraphs 191 and 291 are similar with similarity 1.00
# Paragraphs 191 and 301 are similar with similarity 1.00
# Paragraphs 191 and 312 are similar with similarity 1.00
# Paragraphs 205 and 219 are similar with similarity 1.00
# Paragraphs 205 and 226 are similar with similarity 1.00
# Paragraphs 205 and 260 are similar with similarity 1.00
# Paragraphs 205 and 271 are similar with similarity 1.00
# Paragraphs 205 and 281 are similar with similarity 1.00
# Paragraphs 205 and 291 are similar with similarity 1.00
# Paragraphs 205 and 301 are similar with similarity 1.00
# Paragraphs 205 and 312 are similar with similarity 1.00
# Paragraphs 219 and 226 are similar with similarity 1.00
# Paragraphs 219 and 260 are similar with similarity 1.00
# Paragraphs 219 and 271 are similar with similarity 1.00
# Paragraphs 219 and 281 are similar with similarity 1.00
# Paragraphs 219 and 291 are similar with similarity 1.00
# Paragraphs 219 and 301 are similar with similarity 1.00
# Paragraphs 219 and 312 are similar with similarity 1.00
# Paragraphs 226 and 260 are similar with similarity 1.00
# Paragraphs 226 and 271 are similar with similarity 1.00
# Paragraphs 226 and 281 are similar with similarity 1.00
# Paragraphs 226 and 291 are similar with similarity 1.00
# Paragraphs 226 and 301 are similar with similarity 1.00
# Paragraphs 226 and 312 are similar with similarity 1.00
# Paragraphs 260 and 271 are similar with similarity 1.00
# Paragraphs 260 and 281 are similar with similarity 1.00
# Paragraphs 260 and 291 are similar with similarity 1.00
# Paragraphs 260 and 301 are similar with similarity 1.00
# Paragraphs 260 and 312 are similar with similarity 1.00
# Paragraphs 271 and 281 are similar with similarity 1.00
# Paragraphs 271 and 291 are similar with similarity 1.00
# Paragraphs 271 and 301 are similar with similarity 1.00
# Paragraphs 271 and 312 are similar with similarity 1.00
# Paragraphs 281 and 291 are similar with similarity 1.00
# Paragraphs 281 and 301 are similar with similarity 1.00
# Paragraphs 281 and 312 are similar with similarity 1.00
# Paragraphs 291 and 301 are similar with similarity 1.00
# Paragraphs 291 and 312 are similar with similarity 1.00
# Paragraphs 301 and 312 are similar with similarity 1.00
# Paragraphs 133 and 239 are similar with similarity 1.00
# Paragraphs 133 and 261 are similar with similarity 1.00
# Paragraphs 133 and 272 are similar with similarity 1.00
# Paragraphs 133 and 282 are similar with similarity 1.00
# Paragraphs 133 and 292 are similar with similarity 1.00
# Paragraphs 133 and 303 are similar with similarity 1.00
# Paragraphs 133 and 313 are similar with similarity 1.00
# Paragraphs 239 and 261 are similar with similarity 1.00
# Paragraphs 239 and 272 are similar with similarity 1.00
# Paragraphs 239 and 282 are similar with similarity 1.00
# Paragraphs 239 and 292 are similar with similarity 1.00
# Paragraphs 239 and 303 are similar with similarity 1.00
# Paragraphs 239 and 313 are similar with similarity 1.00
# Paragraphs 261 and 272 are similar with similarity 1.00
# Paragraphs 261 and 282 are similar with similarity 1.00
# Paragraphs 261 and 292 are similar with similarity 1.00
# ...
# Paragraphs 627 and 662 are similar with similarity 1.00
# Paragraphs 634 and 648 are similar with similarity 1.00
# Paragraphs 634 and 662 are similar with similarity 1.00
# Paragraphs 648 and 662 are similar with similarity 1.00
# Paragraphs 627 and 634 are similar with similarity 1.00
# Paragraphs 627 and 648 are similar with similarity 1.00
# Paragraphs 627 and 662 are similar with similarity 1.00
# Paragraphs 634 and 648 are similar with similarity 1.00
# Paragraphs 634 and 662 are similar with similarity 1.00
# Paragraphs 648 and 662 are similar with similarity 1.00
# Paragraphs 627 and 634 are similar with similarity 1.00
# Paragraphs 627 and 648 are similar with similarity 1.00
# Paragraphs 627 and 662 are similar with similarity 1.00
# Paragraphs 634 and 648 are similar with similarity 1.00
# Paragraphs 634 and 662 are similar with similarity 1.00
# Paragraphs 648 and 662 are similar with similarity 1.00
# Paragraphs 628 and 635 are similar with similarity 1.00
# Paragraphs 628 and 649 are similar with similarity 1.00
# Paragraphs 628 and 663 are similar with similarity 1.00
# Paragraphs 635 and 649 are similar with similarity 1.00
# Paragraphs 635 and 663 are similar with similarity 1.00
# Paragraphs 649 and 663 are similar with similarity 1.00
# Paragraphs 628 and 635 are similar with similarity 1.00
# Paragraphs 628 and 649 are similar with similarity 1.00
# Paragraphs 628 and 663 are similar with similarity 1.00
# Paragraphs 635 and 649 are similar with similarity 1.00
# Paragraphs 635 and 663 are similar with similarity 1.00
# Paragraphs 649 and 663 are similar with similarity 1.00
# Paragraphs 628 and 635 are similar with similarity 1.00
# Paragraphs 628 and 649 are similar with similarity 1.00
# Paragraphs 628 and 663 are similar with similarity 1.00
# Paragraphs 635 and 649 are similar with similarity 1.00
# Paragraphs 635 and 663 are similar with similarity 1.00
# Paragraphs 649 and 663 are similar with similarity 1.00
# Paragraphs 629 and 636 are similar with similarity 1.00
# Paragraphs 629 and 650 are similar with similarity 1.00
# Paragraphs 629 and 664 are similar with similarity 1.00
# Paragraphs 636 and 650 are similar with similarity 1.00
# Paragraphs 636 and 664 are similar with similarity 1.00
# Paragraphs 650 and 664 are similar with similarity 1.00
# Paragraphs 629 and 636 are similar with similarity 1.00
# Paragraphs 629 and 650 are similar with similarity 1.00
# Paragraphs 629 and 664 are similar with similarity 1.00
# Paragraphs 636 and 650 are similar with similarity 1.00
# Paragraphs 636 and 664 are similar with similarity 1.00
# Paragraphs 650 and 664 are similar with similarity 1.00
# Paragraphs 629 and 636 are similar with similarity 1.00
# Paragraphs 629 and 650 are similar with similarity 1.00
# Paragraphs 629 and 664 are similar with similarity 1.00
# Paragraphs 636 and 650 are similar with similarity 1.00
# Paragraphs 636 and 664 are similar with similarity 1.00
# Paragraphs 650 and 664 are similar with similarity 1.00
# Paragraphs 637 and 651 are similar with similarity 1.00
# Paragraphs 637 and 665 are similar with similarity 1.00
# Paragraphs 651 and 665 are similar with similarity 1.00
# Paragraphs 637 and 651 are similar with similarity 1.00
# Paragraphs 637 and 665 are similar with similarity 1.00
# Paragraphs 651 and 665 are similar with similarity 1.00
# Paragraphs 637 and 651 are similar with similarity 1.00
# Paragraphs 637 and 665 are similar with similarity 1.00
# Paragraphs 651 and 665 are similar with similarity 1.00
# Paragraphs 676 and 692 are similar with similarity 1.00
# Paragraphs 676 and 692 are similar with similarity 1.00
# Paragraphs 676 and 692 are similar with similarity 1.00
# Paragraphs 677 and 693 are similar with similarity 1.00
# Paragraphs 677 and 693 are similar with similarity 1.00
# Paragraphs 677 and 693 are similar with similarity 1.00
# Paragraphs 678 and 694 are similar with similarity 1.00
# Paragraphs 678 and 694 are similar with similarity 1.00
# Paragraphs 678 and 694 are similar with similarity 1.00
# Paragraphs 679 and 695 are similar with similarity 1.00
# Paragraphs 679 and 695 are similar with similarity 1.00
# Paragraphs 679 and 695 are similar with similarity 1.00
# Paragraphs 680 and 696 are similar with similarity 1.00
# Paragraphs 680 and 696 are similar with similarity 1.00
# Paragraphs 680 and 696 are similar with similarity 1.00
# Paragraphs 681 and 697 are similar with similarity 1.00
# Paragraphs 681 and 697 are similar with similarity 1.00
# Paragraphs 681 and 697 are similar with similarity 1.00
# Paragraphs 682 and 698 are similar with similarity 1.00
# Paragraphs 682 and 698 are similar with similarity 1.00
# Paragraphs 682 and 698 are similar with similarity 1.00
# Paragraphs 683 and 699 are similar with similarity 1.00
# Paragraphs 683 and 699 are similar with similarity 1.00
# Paragraphs 683 and 699 are similar with similarity 1.00
# Paragraphs 684 and 700 are similar with similarity 1.00
# Paragraphs 684 and 700 are similar with similarity 1.00
# Paragraphs 684 and 700 are similar with similarity 1.00
# Paragraphs 685 and 701 are similar with similarity 1.00
# Paragraphs 685 and 701 are similar with similarity 1.00
# Paragraphs 685 and 701 are similar with similarity 1.00
# Paragraphs 686 and 702 are similar with similarity 1.00
# Paragraphs 686 and 702 are similar with similarity 1.00
# Paragraphs 686 and 702 are similar with similarity 1.00
# Paragraphs 687 and 703 are similar with similarity 1.00
# Paragraphs 687 and 703 are similar with similarity 1.00
# Paragraphs 687 and 703 are similar with similarity 1.00
# Paragraphs 688 and 704 are similar with similarity 1.00
# Paragraphs 688 and 704 are similar with similarity 1.00
# Paragraphs 688 and 704 are similar with similarity 1.00
# Paragraphs 689 and 705 are similar with similarity 1.00
# Paragraphs 689 and 705 are similar with similarity 1.00
# Paragraphs 689 and 705 are similar with similarity 1.00
# Paragraphs 690 and 706 are similar with similarity 1.00
# Paragraphs 690 and 706 are similar with similarity 1.00
# Paragraphs 690 and 706 are similar with similarity 1.00
# Paragraphs 803 and 831 are similar with similarity 1.00
# Paragraphs 803 and 831 are similar with similarity 1.00
# Paragraphs 803 and 831 are similar with similarity 1.00
# Paragraphs 804 and 833 are similar with similarity 1.00
# Paragraphs 804 and 833 are similar with similarity 1.00
# Paragraphs 804 and 833 are similar with similarity 1.00
# Paragraphs 806 and 836 are similar with similarity 1.00
# Paragraphs 806 and 836 are similar with similarity 1.00
# Paragraphs 806 and 836 are similar with similarity 1.00
# Paragraphs 807 and 837 are similar with similarity 1.00
# Paragraphs 807 and 837 are similar with similarity 1.00
# Paragraphs 807 and 837 are similar with similarity 1.00
# Paragraphs 808 and 838 are similar with similarity 1.00
# Paragraphs 808 and 838 are similar with similarity 1.00
# Paragraphs 808 and 838 are similar with similarity 1.00
# Paragraphs 809 and 839 are similar with similarity 1.00
# Paragraphs 809 and 839 are similar with similarity 1.00
# Paragraphs 809 and 839 are similar with similarity 1.00
# Paragraphs 810 and 840 are similar with similarity 1.00
# Paragraphs 810 and 840 are similar with similarity 1.00
# Paragraphs 810 and 840 are similar with similarity 1.00
# Paragraphs 811 and 834 are similar with similarity 1.00
# Paragraphs 811 and 841 are similar with similarity 1.00
# Paragraphs 834 and 841 are similar with similarity 1.00
# Paragraphs 811 and 834 are similar with similarity 1.00
# Paragraphs 811 and 841 are similar with similarity 1.00
# Paragraphs 834 and 841 are similar with similarity 1.00
# Paragraphs 811 and 834 are similar with similarity 1.00
# Paragraphs 811 and 841 are similar with similarity 1.00
# Paragraphs 834 and 841 are similar with similarity 1.00
# Paragraphs 812 and 842 are similar with similarity 1.00
# Paragraphs 812 and 842 are similar with similarity 1.00
# Paragraphs 812 and 842 are similar with similarity 1.00
# Paragraphs 813 and 843 are similar with similarity 1.00
# Paragraphs 813 and 843 are similar with similarity 1.00
# Paragraphs 813 and 843 are similar with similarity 1.00
# Paragraphs 814 and 844 are similar with similarity 1.00
# Paragraphs 814 and 844 are similar with similarity 1.00
# Paragraphs 814 and 844 are similar with similarity 1.00
# Paragraphs 815 and 845 are similar with similarity 1.00
# Paragraphs 815 and 845 are similar with similarity 1.00
# Paragraphs 815 and 845 are similar with similarity 1.00
# Paragraphs 816 and 846 are similar with similarity 1.00
# Paragraphs 816 and 846 are similar with similarity 1.00
# Paragraphs 816 and 846 are similar with similarity 1.00
# Paragraphs 817 and 847 are similar with similarity 1.00
# Paragraphs 817 and 847 are similar with similarity 1.00
# Paragraphs 817 and 847 are similar with similarity 1.00
# Paragraphs 918 and 956 are similar with similarity 1.00
# Paragraphs 918 and 956 are similar with similarity 1.00
# Paragraphs 918 and 956 are similar with similarity 1.00
# Paragraphs 919 and 957 are similar with similarity 1.00
# Paragraphs 919 and 957 are similar with similarity 1.00
# Paragraphs 919 and 957 are similar with similarity 1.00
# Paragraphs 920 and 958 are similar with similarity 1.00
# Paragraphs 920 and 958 are similar with similarity 1.00
# Paragraphs 920 and 958 are similar with similarity 1.00
# Paragraphs 921 and 959 are similar with similarity 1.00
# Paragraphs 921 and 959 are similar with similarity 1.00
# Paragraphs 921 and 959 are similar with similarity 1.00
# Paragraphs 922 and 939 are similar with similarity 0.94
# Paragraphs 922 and 960 are similar with similarity 1.00
# Paragraphs 939 and 960 are similar with similarity 0.94
# Paragraphs 922 and 939 are similar with similarity 0.94
# Paragraphs 922 and 960 are similar with similarity 1.00
# Paragraphs 939 and 960 are similar with similarity 0.94
# Paragraphs 922 and 960 are similar with similarity 1.00
# Paragraphs 923 and 940 are similar with similarity 1.00
# Paragraphs 923 and 961 are similar with similarity 1.00
# Paragraphs 940 and 961 are similar with similarity 1.00
# Paragraphs 923 and 940 are similar with similarity 1.00
# Paragraphs 923 and 961 are similar with similarity 1.00
# Paragraphs 940 and 961 are similar with similarity 1.00
# Paragraphs 923 and 940 are similar with similarity 1.00
# Paragraphs 923 and 961 are similar with similarity 1.00
# Paragraphs 940 and 961 are similar with similarity 1.00
# Paragraphs 924 and 941 are similar with similarity 1.00
# Paragraphs 924 and 962 are similar with similarity 1.00
# Paragraphs 941 and 962 are similar with similarity 1.00
# Paragraphs 924 and 941 are similar with similarity 1.00
# Paragraphs 924 and 962 are similar with similarity 1.00
# Paragraphs 941 and 962 are similar with similarity 1.00
# Paragraphs 924 and 941 are similar with similarity 1.00
# Paragraphs 924 and 962 are similar with similarity 1.00
# Paragraphs 941 and 962 are similar with similarity 1.00
# Paragraphs 925 and 942 are similar with similarity 1.00
# Paragraphs 925 and 963 are similar with similarity 1.00
# Paragraphs 942 and 963 are similar with similarity 1.00
# Paragraphs 925 and 942 are similar with similarity 1.00
# Paragraphs 925 and 963 are similar with similarity 1.00
# Paragraphs 942 and 963 are similar with similarity 1.00
# Paragraphs 925 and 942 are similar with similarity 1.00
# Paragraphs 925 and 963 are similar with similarity 1.00
# Paragraphs 942 and 963 are similar with similarity 1.00
# Paragraphs 926 and 943 are similar with similarity 1.00
# Paragraphs 926 and 964 are similar with similarity 1.00
# Paragraphs 943 and 964 are similar with similarity 1.00
# Paragraphs 926 and 943 are similar with similarity 1.00
# Paragraphs 926 and 964 are similar with similarity 1.00
# Paragraphs 943 and 964 are similar with similarity 1.00
# Paragraphs 926 and 943 are similar with similarity 1.00
# Paragraphs 926 and 964 are similar with similarity 1.00
# Paragraphs 943 and 964 are similar with similarity 1.00
# Paragraphs 927 and 944 are similar with similarity 1.00
# Paragraphs 927 and 965 are similar with similarity 1.00
# Paragraphs 944 and 965 are similar with similarity 1.00
# Paragraphs 927 and 944 are similar with similarity 1.00
# Paragraphs 927 and 965 are similar with similarity 1.00
# Paragraphs 944 and 965 are similar with similarity 1.00
# Paragraphs 927 and 944 are similar with similarity 1.00
# Paragraphs 927 and 965 are similar with similarity 1.00
# Paragraphs 944 and 965 are similar with similarity 1.00
# Paragraphs 928 and 945 are similar with similarity 1.00
# Paragraphs 928 and 966 are similar with similarity 1.00
# Paragraphs 945 and 966 are similar with similarity 1.00
# Paragraphs 928 and 945 are similar with similarity 1.00
# Paragraphs 928 and 966 are similar with similarity 1.00
# Paragraphs 945 and 966 are similar with similarity 1.00
# Paragraphs 928 and 945 are similar with similarity 1.00
# Paragraphs 928 and 966 are similar with similarity 1.00
# Paragraphs 945 and 966 are similar with similarity 1.00
# Paragraphs 929 and 946 are similar with similarity 1.00
# Paragraphs 929 and 967 are similar with similarity 1.00
# Paragraphs 946 and 967 are similar with similarity 1.00
# Paragraphs 929 and 946 are similar with similarity 1.00
# Paragraphs 929 and 967 are similar with similarity 1.00
# Paragraphs 946 and 967 are similar with similarity 1.00
# Paragraphs 929 and 946 are similar with similarity 1.00
# Paragraphs 929 and 967 are similar with similarity 1.00
# Paragraphs 946 and 967 are similar with similarity 1.00
# Paragraphs 930 and 947 are similar with similarity 1.00
# Paragraphs 930 and 947 are similar with similarity 1.00
# Paragraphs 930 and 947 are similar with similarity 1.00
# Paragraphs 931 and 948 are similar with similarity 1.00
# Paragraphs 931 and 948 are similar with similarity 1.00
# Paragraphs 931 and 948 are similar with similarity 1.00
# Paragraphs 932 and 949 are similar with similarity 1.00
# Paragraphs 932 and 949 are similar with similarity 1.00
# Paragraphs 932 and 949 are similar with similarity 1.00
# Paragraphs 933 and 950 are similar with similarity 1.00
# Paragraphs 933 and 950 are similar with similarity 1.00
# Paragraphs 933 and 950 are similar with similarity 1.00
# Paragraphs 934 and 951 are similar with similarity 1.00
# Paragraphs 934 and 951 are similar with similarity 1.00
# Paragraphs 934 and 951 are similar with similarity 1.00
# Paragraphs 935 and 952 are similar with similarity 1.00
# Paragraphs 935 and 952 are similar with similarity 1.00
# Paragraphs 935 and 952 are similar with similarity 1.00
# Paragraphs 936 and 953 are similar with similarity 1.00
# Paragraphs 936 and 953 are similar with similarity 1.00
# Paragraphs 936 and 953 are similar with similarity 1.00
# Paragraphs 937 and 954 are similar with similarity 1.00
# Paragraphs 937 and 954 are similar with similarity 1.00
# Paragraphs 937 and 954 are similar with similarity 1.00
# Paragraphs 938 and 955 are similar with similarity 1.00
# Paragraphs 938 and 955 are similar with similarity 1.00
# Paragraphs 938 and 955 are similar with similarity 1.00
# Paragraphs 1068 and 1081 are similar with similarity 1.00
# Paragraphs 1068 and 1081 are similar with similarity 1.00
# Paragraphs 1068 and 1081 are similar with similarity 1.00
# Paragraphs 1069 and 1084 are similar with similarity 1.00
# Paragraphs 1069 and 1084 are similar with similarity 1.00
# Paragraphs 1069 and 1084 are similar with similarity 1.00
# Paragraphs 1116 and 1175 are similar with similarity 1.00
# Paragraphs 1116 and 1175 are similar with similarity 1.00
# Paragraphs 1116 and 1175 are similar with similarity 1.00
# Paragraphs 1117 and 1176 are similar with similarity 1.00
# Paragraphs 1117 and 1176 are similar with similarity 1.00
# Paragraphs 1117 and 1176 are similar with similarity 1.00
# Paragraphs 1118 and 1177 are similar with similarity 1.00
# Paragraphs 1118 and 1177 are similar with similarity 1.00
# Paragraphs 1118 and 1177 are similar with similarity 1.00
# Paragraphs 1119 and 1178 are similar with similarity 1.00
# Paragraphs 1119 and 1178 are similar with similarity 1.00
# Paragraphs 1119 and 1178 are similar with similarity 1.00
# Paragraphs 1120 and 1179 are similar with similarity 1.00
# Paragraphs 1120 and 1179 are similar with similarity 1.00
# Paragraphs 1120 and 1179 are similar with similarity 1.00

# %% [markdown]
# 1.
# Chose shingle size k = 5 to avoid common 2 or 3 word phrases. It represents a good trade-off between generating a lot of shingles if a smaller k was used while also generating enough to detect patterns among similar paragraphs.
#
# 2.
# Naive comparison of Minhash signatures is extremely inefficient requiring a quadratic number of comparisons. The Banding Technique and LSH improves efficiency by focusing only on likely similar document pairs, filtering out pairs that are not likely to be similar.
#
# 3.
# My analysis identified a large number of paragraph pairs that have identical similarity scores. For certain pairs they are indeed identical (119, 247) but I am not sure they are completely identical for every identified pair. Minhash signatures of certain paragraphs could be the same, but the actual paragraphs may not actually be identical.
